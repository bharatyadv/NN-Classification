# %%
##importing iris dataset (universal)

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
##spliting dataset in training and testing
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

##building simple model using keras
##with 2 dense layer first having 20 neurons(relu activation) and second having 10 neurons(softmax activation)
model = Sequential([
    Dense(20, activation='relu', input_shape=(4,)),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
##training model for 100 epochs and using 20% data for validation
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 49ms/step - loss: 4.2303 - accuracy: 0.0000e+00 - val_loss: 4.0987 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 3/3 [==============================] - 0s 10ms/step - loss: 4.0457 - accuracy: 0.0000e+00 - val_loss: 3.9051 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 3/3 [==============================] - 0s 10ms/step - loss: 3.8642 - accuracy: 0.0000e+00 - val_loss: 3.7153 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 3/3 [==============================] - 0s 11ms/step - loss: 3.6850 - accuracy: 0.0000e+00 - val_loss: 3.5292 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 3/3 [==============================] - 0s 10ms/step - loss: 3.5125 - accuracy: 0.0000e+00 - val_loss: 3.3461 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 3/3 [==============================] - 0s 10ms/step - loss: 3.3436 - accuracy: 0.0000e+00 - val_loss: 3.1666 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...

# %%
##evaluating accuracy of model
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5136 - accuracy: 0.9667
# Accuracy: 96.67%

# %%
##ploting model accuracy and loss
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
